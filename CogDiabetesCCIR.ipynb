# %%
import pandas as pd
import numpy as np
from scipy.misc import electrocardiogram
import wfdb as wd
import os

# %%
pip install wfdb
# Out:
# Collecting wfdb
#   Obtaining dependency information for wfdb from https://files.pythonhosted.org/packages/ce/00/b83d0bd64384455dbc1f8eccb7b5d6dac23728515a9d4d74aa4def6c6fe4/wfdb-4.1.2-py3-none-any.whl.metadata
#   Downloading wfdb-4.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: SoundFile>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wfdb) (3.7.2)
# Requirement already satisfied: numpy>=1.10.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wfdb) (1.24.4)
# Requirement already satisfied: pandas>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wfdb) (2.0.3)
# Requirement already satisfied: requests>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wfdb) (2.31.0)
# Requirement already satisfied: scipy>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wfdb) (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.2.2->wfdb) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.2.2->wfdb) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.2.2->wfdb) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/shrivassudharsan/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.2.2->wfdb) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.2.2->wfdb) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shrivassudharsan/Library/Python/3.11/lib/python/site-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.3.0->wfdb) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.3.0->wfdb) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.8.1->wfdb) (2023.7.22)
# Requirement already satisfied: cffi>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from SoundFile>=0.10.0->wfdb) (1.15.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in /Users/shrivassudharsan/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# from scipy import signal
# import matplotlib.pyplot as plt
# from sklearn import preprocessing
# from scipy import signal

# %%
import numpy as np
#myarray = np.fromfile('/Users/shrivassudharsan/Desktop/Data for CCIR/S0283ECG.dat', dtype=float)
print(myarray.mean())
print(myarray.max())
print(myarray)
# Out:
# 4.518269229631619e-158
# 1.740992633756969e-157
# [9.20925074e-158 1.25299395e-308 9.66448562e-158 ... 5.49043334e-158
#  5.05974909e-158 5.49043682e-158]

# %%
signals, fields = wd.rdsamp('/Users/shrivassudharsan/Desktop/Data for CCIR/s0264DC')

# %%
print(signals)
# Out:
# [[-3.8900e+02  3.8500e+02  1.5092e+04 ... -9.0000e+00  6.5400e+02
#    9.0000e+00]
#  [-3.8700e+02  3.8100e+02  1.5094e+04 ...  6.0000e+00  6.5300e+02
#    1.0000e+01]
#  [-3.8500e+02  3.7800e+02  1.5094e+04 ... -4.0000e+00  6.5400e+02
#    1.0000e+01]
#  ...
#  [ 1.0000e+01  2.0000e+00  1.5064e+04 ...  8.1140e+03  7.9990e+03
#    8.0070e+03]
#  [ 1.0000e+01  1.0000e+00  1.5064e+04 ...  8.1150e+03  7.9990e+03
#    8.0080e+03]
#  [ 1.0000e+01  1.0000e+00  1.5064e+04 ...  8.1150e+03  8.0000e+03
#    8.0080e+03]]

# %%
print(signals.shape)
x = signals.shape
# Out:
# (1585698, 8)

# %%
from scipy.misc import electrocardiogram
from scipy import signal
import matplotlib.pyplot as plt

# %%
# Out:
# (115759068,)
# [9.20925074e-158 1.25299395e-308 9.66448562e-158 ... 5.49043334e-158
#  5.05974909e-158 5.49043682e-158]

# %%
fs = 1000
ecg = signals[:,1]
selected_ecg = ecg[519*fs : 529*fs]

plt.figure(figsize = (20,5))
plt.plot(selected_ecg)

number=random.randrage(30)

# %%
number=x.randrage(30) 
print(number)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 number=x.randrage(30)
#       2 print(number)
#
# AttributeError: 'tuple' object has no attribute 'randrage'

# %%
def normalize_ecg_signals(ecg_signals):
    if len(ecg_signals.shape) == 1:
        ecg_signals = ecg_signals.reshape(-1, 1)
    mean = np.mean(ecg_signals, axis=0)
    std = np.std(ecg_signals, axis=0)
    normalized_ecg_signals = (ecg_signals - mean) / std

    return normalized_ecg_signals

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have already loaded myarray and defined fs

# Adjust the amplitude if needed

time = np.arange(0, myarray.shape[0]) / fs

plt.figure(figsize=(20, 5))
plt.plot(time, myarray)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.title('ECG Signal')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 8
#       2 import matplotlib.pyplot as plt
#       4 # Assuming you have already loaded myarray and defined fs
#       5
#       6 # Adjust the amplitude if needed
# ----> 8 time = np.arange(0, myarray.shape[0]) / fs
#      10 plt.figure(figsize=(20, 5))
#      11 plt.plot(time, myarray)
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
import random

def load(filename_1):
    sampling_rate = 1000
    signals, fields = wd.rdsamp(filename_1)
    ecg = signals[:,1]
    total_duration = len(ecg) / sampling_rate
    random_start_time = random.uniform(0, total_duration - 30)


    start_index = int(random_start_time * sampling_rate)
    end_index = start_index + int(30 * sampling_rate)

    random_window = ecg[start_index:end_index]
    plt.figure(figsize = (20,5))
    plt.plot(random_window)

# %%
load('/Users/shrivassudharsan/Desktop/Data for CCIR/s0264DC')

# %%
all_data = os.listdir('/Users/shrivassudharsan/Desktop/Data for CCIR')
list_data = []
for i in range(len(all_data)):
    filename = str(all_data[i])
    datfiles = filename.endswith('dat')
    if datfiles == True:
        list_data.append(filename)



for i in range(len(list_data)):
    x = list_data[i].rstrip(".dat")
    load(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[113], line 13
#      11 for i in range(len(list_data)):
#      12     x = list_data[i].rstrip(".dat")
# ---> 13     load(x)
#
# Cell In[84], line 5, in load(filename_1)
#       3 def load(filename_1):
#       4     sampling_rate = 1000
# ----> 5     signals, fields = wd.rdsamp(filename_1)
#       6     ecg = signals[:,1]
#       7     total_duration = len(ecg) / sampling_rate
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wfdb/io/record.py:2317, in rdsamp(record_name, sampfrom, sampto, channels, pn_dir, channel_names, warn_empty, return_res)
#    2312     dir_list = pn_dir.split("/")
#    2313     pn_dir = posixpath.join(
#    2314         dir_list[0], download.get_version(dir_list[0]), *dir_list[1:]
#    2315     )
# -> 2317 record = rdrecord(
#    2318     record_name=record_name,
#    2319     sampfrom=sampfrom,
#    2320     sampto=sampto,
#    2321     channels=channels,
#    2322     physical=True,
#    2323     pn_dir=pn_dir,
#    2324     m2s=True,
#    2325     return_res=return_res,
#    2326     channel_names=channel_names,
#    2327     warn_empty=warn_empty,
#    2328 )
#    2330 signals = record.p_signal
#    2331 fields = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wfdb/io/record.py:2029, in rdrecord(record_name, sampfrom, sampto, channels, physical, pn_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    2024     dir_list = pn_dir.split("/")
#    2025     pn_dir = posixpath.join(
#    2026         dir_list[0], download.get_version(dir_list[0]), *dir_list[1:]
#    2027     )
# -> 2029 record = rdheader(record_name, pn_dir=pn_dir, rd_segments=False)
#    2031 # Set defaults for sampto and channels input variables
#    2032 if sampto is None:
#    2033     # If the header does not contain the signal length, figure it
#    2034     # out from the first dat file. This is only possible for single
#    2035     # segment records. If there are no signals, sig_len is 0.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wfdb/io/record.py:1839, in rdheader(record_name, pn_dir, rd_segments)
#    1837 file_name = f"{base_record_name}.hea"
#    1838 if pn_dir is None:
# -> 1839     with open(
#    1840         os.path.join(dir_name, file_name),
#    1841         "r",
#    1842         encoding="ascii",
#    1843         errors="ignore",
#    1844     ) as f:
#    1845         header_content = f.read()
#    1846 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/shrivassudharsan/Desktop/s0292DB.hea'

# %%
print(filename)
# Out:
# s0304DB.hea

# %%
print(all_data)
# Out:
# ['s0304DB.hea', 's0339DB.hea', 's0292DB.dat', 's0372DB.dat', 'S0390ECG.dat', 's0308DB.dat', 's0432DB.hea', 'S0300ECG.dat', 's0250DC.dat', '.DS_Store', 's0328DB.dat', 's0283DB.hea', 'S0441ECG.dat', 's0254DB.dat', 's0326DB.hea', 'S0427ECG.hea', 's0256DB.dat', 'S0435ECG.hea', 'S0411ECG.hea', 'S0318ECG.dat', 's0368DC.dat', 's0366DB.hea', 's0318DB.hea', 's0264DC.hea', 's0435DC.hea', 's0314DB.dat', 'S0283ECG.hea', 's0435DC.dat', 's0318DB.dat', 's0264DC.dat', 'S0283ECG.dat', 's0314DB.hea', 's0368DC.hea', 's0366DB.dat', 'S0327ECG.dat', 's0283DB.dat', 's0254DB.hea', 'S0441ECG.hea', 's0326DB.dat', 's0328DB.hea', 'S0411ECG.dat', 'S0435ECG.dat', 's0256DB.hea', 'S0250ECG.dat', 's0292DB.hea', 's0372DB.hea', 'S0317ECG.dat', 's0339DB.dat', 's0304DB.dat', 's0250DC.hea', 'voice001.dat', 'S0300ECG.hea', 's0432DB.dat', 's0308DB.hea']

# %%
x = normalize_ecg_signals(myarray)
print(x)
# Out:
# [[nan]
#  [nan]
#  [nan]
#  ...
#  [nan]
#  [nan]
#  [nan]]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:181: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:181: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:215: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:215: RuntimeWarning: invalid value encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:236: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /var/folders/9x/clw12fjd1yj8w1q9wz6hk4cm0000gn/T/ipykernel_15439/1538128515.py:6: RuntimeWarning: invalid value encountered in subtract
#   normalized_ecg_signals = (ecg_signals - mean) / std

# %%
def downsample_ecg_signals(ecg_signals, original_sampling_rate, target_sampling_rate=200):
    resampling_factor = target_sampling_rate / original_sampling_rate
    downsampled_ecg_signals = signal.resample(ecg_signals, int(ecg_signals.shape[0] * resampling_factor), axis=0)
    return downsampled_ecg_signals

# %%
y = downsample_ecg_signals(myarray, 1000, 2)
print(y)
